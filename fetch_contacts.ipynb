# %% [markdown]
# # ActiveCampaign Contacts - Read Only
#
# This notebook fetches all contacts from ActiveCampaign API (READ ONLY - no modifications) and loads them into a pandas DataFrame with all available datapoints.
#
# ⚠️ **This notebook only reads data. No changes will be made to ActiveCampaign.**

# %%
import os
import pandas as pd
import requests
from dotenv import load_dotenv
import json
from typing import List, Dict, Any

# Load environment variables
load_dotenv()

# ActiveCampaign configuration
ACTIVE_CAMPAIGN_API_KEY = os.environ.get('ACTIVE_CAMPAIGN_API_KEY')
API_URL = os.environ.get('API_URL')

headers = {
    "Api-Token": ACTIVE_CAMPAIGN_API_KEY,
    "Content-Type": "application/json",
}

print(f"API URL: {API_URL}")
print(f"API Key configured: {'Yes' if ACTIVE_CAMPAIGN_API_KEY else 'No'}")
# Out:
# API URL: https://ehb.api-us1.com
# API Key configured: Yes

# %%
import time
from datetime import timedelta

def fetch_all_contacts(api_url: str, headers: Dict[str, str], limit: int = 100) -> List[Dict[str, Any]]:
    """
    Fetch all contacts from ActiveCampaign API with pagination (READ ONLY).
    Includes custom field values (fieldValues) in the request.
    
    Args:
        api_url: Base API URL
        headers: Request headers with API token
        limit: Number of contacts per page (max 100)
    
    Returns:
        List of all contact records with all available datapoints
    """
    all_contacts = []
    offset = 0
    batch_num = 0
    start_time = time.time()
    
    print("=" * 80)
    print("FETCHING CONTACTS FROM ACTIVECAMPAIGN (READ ONLY)")
    print("=" * 80)
    
    while True:
        # Using GET request with fieldValues included - read only, no modifications
        url = f"{api_url}/api/3/contacts?include=fieldValues&limit={limit}&offset={offset}"
        batch_num += 1
        batch_start = time.time()
        
        try:
            response = requests.get(url, headers=headers)  # GET only - no modifications
            response.raise_for_status()
            
            batch_elapsed = time.time() - batch_start
            
            data = response.json()
            contacts = data.get('contacts', [])
            
            if not contacts:
                print("\n✓ No more contacts found. Fetch complete!")
                break
                
            all_contacts.extend(contacts)
            
            # Calculate metrics
            total_elapsed = time.time() - start_time
            contacts_per_second = len(all_contacts) / total_elapsed if total_elapsed > 0 else 0
            
            # Print detailed status
            print(f"\n📦 Batch #{batch_num}")
            print(f"   ├─ Retrieved: {len(contacts)} contacts in {batch_elapsed:.2f}s")
            print(f"   ├─ Offset: {offset}")
            print(f"   ├─ Total so far: {len(all_contacts):,} contacts")
            print(f"   ├─ Speed: {contacts_per_second:.1f} contacts/sec")
            print(f"   └─ Elapsed time: {timedelta(seconds=int(total_elapsed))}")
            
            # If we got fewer contacts than the limit, we've reached the end
            if len(contacts) < limit:
                print("\n✓ Reached end of contacts (last page).")
                break
                
            offset += limit
            
        except requests.exceptions.RequestException as e:
            print(f"\n❌ Error fetching contacts: {e}")
            break
    
    # Final summary
    total_time = time.time() - start_time
    avg_speed = len(all_contacts) / total_time if total_time > 0 else 0
    
    print("\n" + "=" * 80)
    print("FETCH SUMMARY")
    print("=" * 80)
    print(f"✓ Total contacts retrieved: {len(all_contacts):,}")
    print(f"✓ Total batches: {batch_num}")
    print(f"✓ Total time: {timedelta(seconds=int(total_time))} ({total_time:.2f}s)")
    print(f"✓ Average speed: {avg_speed:.1f} contacts/sec")
    print(f"✓ Batch size: {limit}")
    print(f"✓ Includes: Custom field values (fieldValues)")
    print("=" * 80)
    
    return all_contacts

# Fetch all contacts (READ ONLY operation)
contacts = fetch_all_contacts(API_URL, headers, limit=100)
# Out:
# ================================================================================
# FETCHING CONTACTS FROM ACTIVECAMPAIGN (READ ONLY)
# ================================================================================
#
# 📦 Batch #1
#    ├─ Retrieved: 100 contacts in 1.08s
#    ├─ Offset: 0
#    ├─ Total so far: 100 contacts
#    ├─ Speed: 92.1 contacts/sec
#    └─ Elapsed time: 0:00:01
#
# 📦 Batch #2
#    ├─ Retrieved: 100 contacts in 0.96s
#    ├─ Offset: 100
#    ├─ Total so far: 200 contacts
#    ├─ Speed: 97.6 contacts/sec
#    └─ Elapsed time: 0:00:02
#
# 📦 Batch #3
#    ├─ Retrieved: 100 contacts in 0.94s
#    ├─ Offset: 200
#    ├─ Total so far: 300 contacts
#    ├─ Speed: 100.1 contacts/sec
#    └─ Elapsed time: 0:00:02
#
# 📦 Batch #4
#    ├─ Retrieved: 100 contacts in 0.94s
#    ├─ Offset: 300
#    ├─ Total so far: 400 contacts
#    ├─ Speed: 101.5 contacts/sec
#    └─ Elapsed time: 0:00:03
#
# 📦 Batch #5
#    ├─ Retrieved: 100 contacts in 0.93s
#    ├─ Offset: 400
#    ├─ Total so far: 500 contacts
#    ├─ Speed: 102.6 contacts/sec
#    └─ Elapsed time: 0:00:04
#
# 📦 Batch #6
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 500
#    ├─ Total so far: 600 contacts
#    ├─ Speed: 107.5 contacts/sec
#    └─ Elapsed time: 0:00:05
#
# 📦 Batch #7
#    ├─ Retrieved: 100 contacts in 0.80s
#    ├─ Offset: 600
#    ├─ Total so far: 700 contacts
#    ├─ Speed: 109.6 contacts/sec
#    └─ Elapsed time: 0:00:06
#
# 📦 Batch #8
#    ├─ Retrieved: 100 contacts in 0.76s
#    ├─ Offset: 700
#    ├─ Total so far: 800 contacts
#    ├─ Speed: 112.0 contacts/sec
#    └─ Elapsed time: 0:00:07
#
# 📦 Batch #9
#    ├─ Retrieved: 100 contacts in 0.82s
#    ├─ Offset: 800
#    ├─ Total so far: 900 contacts
#    ├─ Speed: 113.0 contacts/sec
#    └─ Elapsed time: 0:00:07
#
# 📦 Batch #10
#    ├─ Retrieved: 100 contacts in 0.78s
#    ├─ Offset: 900
#    ├─ Total so far: 1,000 contacts
#    ├─ Speed: 114.3 contacts/sec
#    └─ Elapsed time: 0:00:08
#
# 📦 Batch #11
#    ├─ Retrieved: 100 contacts in 1.85s
#    ├─ Offset: 1000
#    ├─ Total so far: 1,100 contacts
#    ├─ Speed: 103.7 contacts/sec
#    └─ Elapsed time: 0:00:10
#
# 📦 Batch #12
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 1100
#    ├─ Total so far: 1,200 contacts
#    ├─ Speed: 106.0 contacts/sec
#    └─ Elapsed time: 0:00:11
#
# 📦 Batch #13
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 1200
#    ├─ Total so far: 1,300 contacts
#    ├─ Speed: 107.9 contacts/sec
#    └─ Elapsed time: 0:00:12
#
# 📦 Batch #14
#    ├─ Retrieved: 100 contacts in 0.80s
#    ├─ Offset: 1300
#    ├─ Total so far: 1,400 contacts
#    ├─ Speed: 108.9 contacts/sec
#    └─ Elapsed time: 0:00:12
#
# 📦 Batch #15
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 1400
#    ├─ Total so far: 1,500 contacts
#    ├─ Speed: 110.6 contacts/sec
#    └─ Elapsed time: 0:00:13
#
# 📦 Batch #16
#    ├─ Retrieved: 100 contacts in 0.82s
#    ├─ Offset: 1500
#    ├─ Total so far: 1,600 contacts
#    ├─ Speed: 111.2 contacts/sec
#    └─ Elapsed time: 0:00:14
#
# 📦 Batch #17
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 1600
#    ├─ Total so far: 1,700 contacts
#    ├─ Speed: 112.8 contacts/sec
#    └─ Elapsed time: 0:00:15
#
# 📦 Batch #18
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 1700
#    ├─ Total so far: 1,800 contacts
#    ├─ Speed: 114.5 contacts/sec
#    └─ Elapsed time: 0:00:15
#
# 📦 Batch #19
#    ├─ Retrieved: 100 contacts in 0.76s
#    ├─ Offset: 1800
#    ├─ Total so far: 1,900 contacts
#    ├─ Speed: 115.2 contacts/sec
#    └─ Elapsed time: 0:00:16
#
# 📦 Batch #20
#    ├─ Retrieved: 100 contacts in 0.55s
#    ├─ Offset: 1900
#    ├─ Total so far: 2,000 contacts
#    ├─ Speed: 117.3 contacts/sec
#    └─ Elapsed time: 0:00:17
#
# 📦 Batch #21
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 2000
#    ├─ Total so far: 2,100 contacts
#    ├─ Speed: 118.6 contacts/sec
#    └─ Elapsed time: 0:00:17
#
# 📦 Batch #22
#    ├─ Retrieved: 100 contacts in 0.61s
#    ├─ Offset: 2100
#    ├─ Total so far: 2,200 contacts
#    ├─ Speed: 120.1 contacts/sec
#    └─ Elapsed time: 0:00:18
#
# 📦 Batch #23
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 2200
#    ├─ Total so far: 2,300 contacts
#    ├─ Speed: 121.2 contacts/sec
#    └─ Elapsed time: 0:00:18
#
# 📦 Batch #24
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 2300
#    ├─ Total so far: 2,400 contacts
#    ├─ Speed: 122.0 contacts/sec
#    └─ Elapsed time: 0:00:19
#
# 📦 Batch #25
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 2400
#    ├─ Total so far: 2,500 contacts
#    ├─ Speed: 122.6 contacts/sec
#    └─ Elapsed time: 0:00:20
#
# 📦 Batch #26
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 2500
#    ├─ Total so far: 2,600 contacts
#    ├─ Speed: 122.9 contacts/sec
#    └─ Elapsed time: 0:00:21
#
# 📦 Batch #27
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 2600
#    ├─ Total so far: 2,700 contacts
#    ├─ Speed: 123.7 contacts/sec
#    └─ Elapsed time: 0:00:21
#
# 📦 Batch #28
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 2700
#    ├─ Total so far: 2,800 contacts
#    ├─ Speed: 124.6 contacts/sec
#    └─ Elapsed time: 0:00:22
#
# 📦 Batch #29
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 2800
#    ├─ Total so far: 2,900 contacts
#    ├─ Speed: 125.5 contacts/sec
#    └─ Elapsed time: 0:00:23
#
# 📦 Batch #30
#    ├─ Retrieved: 100 contacts in 0.80s
#    ├─ Offset: 2900
#    ├─ Total so far: 3,000 contacts
#    ├─ Speed: 125.4 contacts/sec
#    └─ Elapsed time: 0:00:23
#
# 📦 Batch #31
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 3000
#    ├─ Total so far: 3,100 contacts
#    ├─ Speed: 126.1 contacts/sec
#    └─ Elapsed time: 0:00:24
#
# 📦 Batch #32
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 3100
#    ├─ Total so far: 3,200 contacts
#    ├─ Speed: 126.9 contacts/sec
#    └─ Elapsed time: 0:00:25
#
# 📦 Batch #33
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 3200
#    ├─ Total so far: 3,300 contacts
#    ├─ Speed: 127.6 contacts/sec
#    └─ Elapsed time: 0:00:25
#
# 📦 Batch #34
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 3300
#    ├─ Total so far: 3,400 contacts
#    ├─ Speed: 128.3 contacts/sec
#    └─ Elapsed time: 0:00:26
#
# 📦 Batch #35
#    ├─ Retrieved: 100 contacts in 0.77s
#    ├─ Offset: 3400
#    ├─ Total so far: 3,500 contacts
#    ├─ Speed: 128.3 contacts/sec
#    └─ Elapsed time: 0:00:27
#
# 📦 Batch #36
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 3500
#    ├─ Total so far: 3,600 contacts
#    ├─ Speed: 128.5 contacts/sec
#    └─ Elapsed time: 0:00:28
#
# 📦 Batch #37
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 3600
#    ├─ Total so far: 3,700 contacts
#    ├─ Speed: 129.1 contacts/sec
#    └─ Elapsed time: 0:00:28
#
# 📦 Batch #38
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 3700
#    ├─ Total so far: 3,800 contacts
#    ├─ Speed: 129.7 contacts/sec
#    └─ Elapsed time: 0:00:29
#
# 📦 Batch #39
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 3800
#    ├─ Total so far: 3,900 contacts
#    ├─ Speed: 130.0 contacts/sec
#    └─ Elapsed time: 0:00:29
#
# 📦 Batch #40
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 3900
#    ├─ Total so far: 4,000 contacts
#    ├─ Speed: 130.3 contacts/sec
#    └─ Elapsed time: 0:00:30
#
# 📦 Batch #41
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 4000
#    ├─ Total so far: 4,100 contacts
#    ├─ Speed: 130.8 contacts/sec
#    └─ Elapsed time: 0:00:31
#
# 📦 Batch #42
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 4100
#    ├─ Total so far: 4,200 contacts
#    ├─ Speed: 131.3 contacts/sec
#    └─ Elapsed time: 0:00:31
#
# 📦 Batch #43
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 4200
#    ├─ Total so far: 4,300 contacts
#    ├─ Speed: 131.8 contacts/sec
#    └─ Elapsed time: 0:00:32
#
# 📦 Batch #44
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 4300
#    ├─ Total so far: 4,400 contacts
#    ├─ Speed: 132.3 contacts/sec
#    └─ Elapsed time: 0:00:33
#
# 📦 Batch #45
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 4400
#    ├─ Total so far: 4,500 contacts
#    ├─ Speed: 132.8 contacts/sec
#    └─ Elapsed time: 0:00:33
#
# 📦 Batch #46
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 4500
#    ├─ Total so far: 4,600 contacts
#    ├─ Speed: 133.2 contacts/sec
#    └─ Elapsed time: 0:00:34
#
# 📦 Batch #47
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 4600
#    ├─ Total so far: 4,700 contacts
#    ├─ Speed: 133.5 contacts/sec
#    └─ Elapsed time: 0:00:35
#
# 📦 Batch #48
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 4700
#    ├─ Total so far: 4,800 contacts
#    ├─ Speed: 134.0 contacts/sec
#    └─ Elapsed time: 0:00:35
#
# 📦 Batch #49
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 4800
#    ├─ Total so far: 4,900 contacts
#    ├─ Speed: 134.1 contacts/sec
#    └─ Elapsed time: 0:00:36
#
# 📦 Batch #50
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 4900
#    ├─ Total so far: 5,000 contacts
#    ├─ Speed: 134.5 contacts/sec
#    └─ Elapsed time: 0:00:37
#
# 📦 Batch #51
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 5000
#    ├─ Total so far: 5,100 contacts
#    ├─ Speed: 134.6 contacts/sec
#    └─ Elapsed time: 0:00:37
#
# 📦 Batch #52
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 5100
#    ├─ Total so far: 5,200 contacts
#    ├─ Speed: 135.0 contacts/sec
#    └─ Elapsed time: 0:00:38
#
# 📦 Batch #53
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 5200
#    ├─ Total so far: 5,300 contacts
#    ├─ Speed: 135.2 contacts/sec
#    └─ Elapsed time: 0:00:39
#
# 📦 Batch #54
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 5300
#    ├─ Total so far: 5,400 contacts
#    ├─ Speed: 135.3 contacts/sec
#    └─ Elapsed time: 0:00:39
#
# 📦 Batch #55
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 5400
#    ├─ Total so far: 5,500 contacts
#    ├─ Speed: 135.6 contacts/sec
#    └─ Elapsed time: 0:00:40
#
# 📦 Batch #56
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 5500
#    ├─ Total so far: 5,600 contacts
#    ├─ Speed: 135.5 contacts/sec
#    └─ Elapsed time: 0:00:41
#
# 📦 Batch #57
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 5600
#    ├─ Total so far: 5,700 contacts
#    ├─ Speed: 135.8 contacts/sec
#    └─ Elapsed time: 0:00:41
#
# 📦 Batch #58
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 5700
#    ├─ Total so far: 5,800 contacts
#    ├─ Speed: 136.0 contacts/sec
#    └─ Elapsed time: 0:00:42
#
# 📦 Batch #59
#    ├─ Retrieved: 100 contacts in 0.83s
#    ├─ Offset: 5800
#    ├─ Total so far: 5,900 contacts
#    ├─ Speed: 135.7 contacts/sec
#    └─ Elapsed time: 0:00:43
#
# 📦 Batch #60
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 5900
#    ├─ Total so far: 6,000 contacts
#    ├─ Speed: 136.0 contacts/sec
#    └─ Elapsed time: 0:00:44
#
# 📦 Batch #61
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 6000
#    ├─ Total so far: 6,100 contacts
#    ├─ Speed: 136.2 contacts/sec
#    └─ Elapsed time: 0:00:44
#
# 📦 Batch #62
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 6100
#    ├─ Total so far: 6,200 contacts
#    ├─ Speed: 136.2 contacts/sec
#    └─ Elapsed time: 0:00:45
#
# 📦 Batch #63
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 6200
#    ├─ Total so far: 6,300 contacts
#    ├─ Speed: 136.4 contacts/sec
#    └─ Elapsed time: 0:00:46
#
# 📦 Batch #64
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 6300
#    ├─ Total so far: 6,400 contacts
#    ├─ Speed: 136.7 contacts/sec
#    └─ Elapsed time: 0:00:46
#
# 📦 Batch #65
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 6400
#    ├─ Total so far: 6,500 contacts
#    ├─ Speed: 136.8 contacts/sec
#    └─ Elapsed time: 0:00:47
#
# 📦 Batch #66
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 6500
#    ├─ Total so far: 6,600 contacts
#    ├─ Speed: 136.9 contacts/sec
#    └─ Elapsed time: 0:00:48
#
# 📦 Batch #67
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 6600
#    ├─ Total so far: 6,700 contacts
#    ├─ Speed: 137.0 contacts/sec
#    └─ Elapsed time: 0:00:48
#
# 📦 Batch #68
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 6700
#    ├─ Total so far: 6,800 contacts
#    ├─ Speed: 137.1 contacts/sec
#    └─ Elapsed time: 0:00:49
#
# 📦 Batch #69
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 6800
#    ├─ Total so far: 6,900 contacts
#    ├─ Speed: 137.3 contacts/sec
#    └─ Elapsed time: 0:00:50
#
# 📦 Batch #70
#    ├─ Retrieved: 100 contacts in 0.78s
#    ├─ Offset: 6900
#    ├─ Total so far: 7,000 contacts
#    ├─ Speed: 137.2 contacts/sec
#    └─ Elapsed time: 0:00:51
#
# 📦 Batch #71
#    ├─ Retrieved: 100 contacts in 0.79s
#    ├─ Offset: 7000
#    ├─ Total so far: 7,100 contacts
#    ├─ Speed: 137.0 contacts/sec
#    └─ Elapsed time: 0:00:51
#
# 📦 Batch #72
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 7100
#    ├─ Total so far: 7,200 contacts
#    ├─ Speed: 137.3 contacts/sec
#    └─ Elapsed time: 0:00:52
#
# 📦 Batch #73
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 7200
#    ├─ Total so far: 7,300 contacts
#    ├─ Speed: 137.3 contacts/sec
#    └─ Elapsed time: 0:00:53
#
# 📦 Batch #74
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 7300
#    ├─ Total so far: 7,400 contacts
#    ├─ Speed: 137.5 contacts/sec
#    └─ Elapsed time: 0:00:53
#
# 📦 Batch #75
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 7400
#    ├─ Total so far: 7,500 contacts
#    ├─ Speed: 137.6 contacts/sec
#    └─ Elapsed time: 0:00:54
#
# 📦 Batch #76
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 7500
#    ├─ Total so far: 7,600 contacts
#    ├─ Speed: 137.7 contacts/sec
#    └─ Elapsed time: 0:00:55
#
# 📦 Batch #77
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 7600
#    ├─ Total so far: 7,700 contacts
#    ├─ Speed: 137.8 contacts/sec
#    └─ Elapsed time: 0:00:55
#
# 📦 Batch #78
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 7700
#    ├─ Total so far: 7,800 contacts
#    ├─ Speed: 137.8 contacts/sec
#    └─ Elapsed time: 0:00:56
#
# 📦 Batch #79
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 7800
#    ├─ Total so far: 7,900 contacts
#    ├─ Speed: 138.0 contacts/sec
#    └─ Elapsed time: 0:00:57
#
# 📦 Batch #80
#    ├─ Retrieved: 100 contacts in 0.51s
#    ├─ Offset: 7900
#    ├─ Total so far: 8,000 contacts
#    ├─ Speed: 138.5 contacts/sec
#    └─ Elapsed time: 0:00:57
#
# 📦 Batch #81
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 8000
#    ├─ Total so far: 8,100 contacts
#    ├─ Speed: 138.5 contacts/sec
#    └─ Elapsed time: 0:00:58
#
# 📦 Batch #82
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 8100
#    ├─ Total so far: 8,200 contacts
#    ├─ Speed: 138.6 contacts/sec
#    └─ Elapsed time: 0:00:59
#
# 📦 Batch #83
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 8200
#    ├─ Total so far: 8,300 contacts
#    ├─ Speed: 138.6 contacts/sec
#    └─ Elapsed time: 0:00:59
#
# 📦 Batch #84
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 8300
#    ├─ Total so far: 8,400 contacts
#    ├─ Speed: 138.6 contacts/sec
#    └─ Elapsed time: 0:01:00
#
# 📦 Batch #85
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 8400
#    ├─ Total so far: 8,500 contacts
#    ├─ Speed: 138.7 contacts/sec
#    └─ Elapsed time: 0:01:01
#
# 📦 Batch #86
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 8500
#    ├─ Total so far: 8,600 contacts
#    ├─ Speed: 138.8 contacts/sec
#    └─ Elapsed time: 0:01:01
#
# 📦 Batch #87
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 8600
#    ├─ Total so far: 8,700 contacts
#    ├─ Speed: 139.0 contacts/sec
#    └─ Elapsed time: 0:01:02
#
# 📦 Batch #88
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 8700
#    ├─ Total so far: 8,800 contacts
#    ├─ Speed: 139.1 contacts/sec
#    └─ Elapsed time: 0:01:03
#
# 📦 Batch #89
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 8800
#    ├─ Total so far: 8,900 contacts
#    ├─ Speed: 139.2 contacts/sec
#    └─ Elapsed time: 0:01:03
#
# 📦 Batch #90
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 8900
#    ├─ Total so far: 9,000 contacts
#    ├─ Speed: 139.3 contacts/sec
#    └─ Elapsed time: 0:01:04
#
# 📦 Batch #91
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 9000
#    ├─ Total so far: 9,100 contacts
#    ├─ Speed: 139.4 contacts/sec
#    └─ Elapsed time: 0:01:05
#
# 📦 Batch #92
#    ├─ Retrieved: 100 contacts in 0.76s
#    ├─ Offset: 9100
#    ├─ Total so far: 9,200 contacts
#    ├─ Speed: 139.3 contacts/sec
#    └─ Elapsed time: 0:01:06
#
# 📦 Batch #93
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 9200
#    ├─ Total so far: 9,300 contacts
#    ├─ Speed: 139.4 contacts/sec
#    └─ Elapsed time: 0:01:06
#
# 📦 Batch #94
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 9300
#    ├─ Total so far: 9,400 contacts
#    ├─ Speed: 139.5 contacts/sec
#    └─ Elapsed time: 0:01:07
#
# 📦 Batch #95
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 9400
#    ├─ Total so far: 9,500 contacts
#    ├─ Speed: 139.5 contacts/sec
#    └─ Elapsed time: 0:01:08
#
# 📦 Batch #96
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 9500
#    ├─ Total so far: 9,600 contacts
#    ├─ Speed: 139.6 contacts/sec
#    └─ Elapsed time: 0:01:08
#
# 📦 Batch #97
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 9600
#    ├─ Total so far: 9,700 contacts
#    ├─ Speed: 139.7 contacts/sec
#    └─ Elapsed time: 0:01:09
#
# 📦 Batch #98
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 9700
#    ├─ Total so far: 9,800 contacts
#    ├─ Speed: 139.7 contacts/sec
#    └─ Elapsed time: 0:01:10
#
# 📦 Batch #99
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 9800
#    ├─ Total so far: 9,900 contacts
#    ├─ Speed: 139.8 contacts/sec
#    └─ Elapsed time: 0:01:10
#
# 📦 Batch #100
#    ├─ Retrieved: 100 contacts in 0.57s
#    ├─ Offset: 9900
#    ├─ Total so far: 10,000 contacts
#    ├─ Speed: 140.1 contacts/sec
#    └─ Elapsed time: 0:01:11
#
# 📦 Batch #101
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 10000
#    ├─ Total so far: 10,100 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:01:12
#
# 📦 Batch #102
#    ├─ Retrieved: 100 contacts in 0.61s
#    ├─ Offset: 10100
#    ├─ Total so far: 10,200 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:01:12
#
# 📦 Batch #103
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 10200
#    ├─ Total so far: 10,300 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:01:13
#
# 📦 Batch #104
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 10300
#    ├─ Total so far: 10,400 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:01:13
#
# 📦 Batch #105
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 10400
#    ├─ Total so far: 10,500 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:01:14
#
# 📦 Batch #106
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 10500
#    ├─ Total so far: 10,600 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:01:15
#
# 📦 Batch #107
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 10600
#    ├─ Total so far: 10,700 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:01:15
#
# 📦 Batch #108
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 10700
#    ├─ Total so far: 10,800 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:01:16
#
# 📦 Batch #109
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 10800
#    ├─ Total so far: 10,900 contacts
#    ├─ Speed: 140.9 contacts/sec
#    └─ Elapsed time: 0:01:17
#
# 📦 Batch #110
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 10900
#    ├─ Total so far: 11,000 contacts
#    ├─ Speed: 140.9 contacts/sec
#    └─ Elapsed time: 0:01:18
#
# 📦 Batch #111
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 11000
#    ├─ Total so far: 11,100 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:01:18
#
# 📦 Batch #112
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 11100
#    ├─ Total so far: 11,200 contacts
#    ├─ Speed: 140.9 contacts/sec
#    └─ Elapsed time: 0:01:19
#
# 📦 Batch #113
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 11200
#    ├─ Total so far: 11,300 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:01:20
#
# 📦 Batch #114
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 11300
#    ├─ Total so far: 11,400 contacts
#    ├─ Speed: 141.1 contacts/sec
#    └─ Elapsed time: 0:01:20
#
# 📦 Batch #115
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 11400
#    ├─ Total so far: 11,500 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:01:21
#
# 📦 Batch #116
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 11500
#    ├─ Total so far: 11,600 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:22
#
# 📦 Batch #117
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 11600
#    ├─ Total so far: 11,700 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:01:22
#
# 📦 Batch #118
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 11700
#    ├─ Total so far: 11,800 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:23
#
# 📦 Batch #119
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 11800
#    ├─ Total so far: 11,900 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:01:24
#
# 📦 Batch #120
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 11900
#    ├─ Total so far: 12,000 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:01:24
#
# 📦 Batch #121
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 12000
#    ├─ Total so far: 12,100 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:01:25
#
# 📦 Batch #122
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 12100
#    ├─ Total so far: 12,200 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:01:26
#
# 📦 Batch #123
#    ├─ Retrieved: 100 contacts in 0.77s
#    ├─ Offset: 12200
#    ├─ Total so far: 12,300 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:01:26
#
# 📦 Batch #124
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 12300
#    ├─ Total so far: 12,400 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:27
#
# 📦 Batch #125
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 12400
#    ├─ Total so far: 12,500 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:01:28
#
# 📦 Batch #126
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 12500
#    ├─ Total so far: 12,600 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:01:29
#
# 📦 Batch #127
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 12600
#    ├─ Total so far: 12,700 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:01:29
#
# 📦 Batch #128
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 12700
#    ├─ Total so far: 12,800 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:01:30
#
# 📦 Batch #129
#    ├─ Retrieved: 100 contacts in 0.83s
#    ├─ Offset: 12800
#    ├─ Total so far: 12,900 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:01:31
#
# 📦 Batch #130
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 12900
#    ├─ Total so far: 13,000 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:01:32
#
# 📦 Batch #131
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 13000
#    ├─ Total so far: 13,100 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:01:32
#
# 📦 Batch #132
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 13100
#    ├─ Total so far: 13,200 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:33
#
# 📦 Batch #133
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 13200
#    ├─ Total so far: 13,300 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:34
#
# 📦 Batch #134
#    ├─ Retrieved: 100 contacts in 0.79s
#    ├─ Offset: 13300
#    ├─ Total so far: 13,400 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:01:34
#
# 📦 Batch #135
#    ├─ Retrieved: 100 contacts in 0.81s
#    ├─ Offset: 13400
#    ├─ Total so far: 13,500 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:01:35
#
# 📦 Batch #136
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 13500
#    ├─ Total so far: 13,600 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:01:36
#
# 📦 Batch #137
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 13600
#    ├─ Total so far: 13,700 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:01:37
#
# 📦 Batch #138
#    ├─ Retrieved: 100 contacts in 0.61s
#    ├─ Offset: 13700
#    ├─ Total so far: 13,800 contacts
#    ├─ Speed: 141.1 contacts/sec
#    └─ Elapsed time: 0:01:37
#
# 📦 Batch #139
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 13800
#    ├─ Total so far: 13,900 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:01:38
#
# 📦 Batch #140
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 13900
#    ├─ Total so far: 14,000 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:39
#
# 📦 Batch #141
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 14000
#    ├─ Total so far: 14,100 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:39
#
# 📦 Batch #142
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 14100
#    ├─ Total so far: 14,200 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:40
#
# 📦 Batch #143
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 14200
#    ├─ Total so far: 14,300 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:01:41
#
# 📦 Batch #144
#    ├─ Retrieved: 100 contacts in 0.79s
#    ├─ Offset: 14300
#    ├─ Total so far: 14,400 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:01:41
#
# 📦 Batch #145
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 14400
#    ├─ Total so far: 14,500 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:01:42
#
# 📦 Batch #146
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 14500
#    ├─ Total so far: 14,600 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:01:43
#
# 📦 Batch #147
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 14600
#    ├─ Total so far: 14,700 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:01:43
#
# 📦 Batch #148
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 14700
#    ├─ Total so far: 14,800 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:01:44
#
# 📦 Batch #149
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 14800
#    ├─ Total so far: 14,900 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:01:45
#
# 📦 Batch #150
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 14900
#    ├─ Total so far: 15,000 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:01:45
#
# 📦 Batch #151
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 15000
#    ├─ Total so far: 15,100 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:01:46
#
# 📦 Batch #152
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 15100
#    ├─ Total so far: 15,200 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:01:47
#
# 📦 Batch #153
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 15200
#    ├─ Total so far: 15,300 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:01:48
#
# 📦 Batch #154
#    ├─ Retrieved: 100 contacts in 0.80s
#    ├─ Offset: 15300
#    ├─ Total so far: 15,400 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:01:48
#
# 📦 Batch #155
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 15400
#    ├─ Total so far: 15,500 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:01:49
#
# 📦 Batch #156
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 15500
#    ├─ Total so far: 15,600 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:01:50
#
# 📦 Batch #157
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 15600
#    ├─ Total so far: 15,700 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:01:50
#
# 📦 Batch #158
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 15700
#    ├─ Total so far: 15,800 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:01:51
#
# 📦 Batch #159
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 15800
#    ├─ Total so far: 15,900 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:01:52
#
# 📦 Batch #160
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 15900
#    ├─ Total so far: 16,000 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:01:52
#
# 📦 Batch #161
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 16000
#    ├─ Total so far: 16,100 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:01:53
#
# 📦 Batch #162
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 16100
#    ├─ Total so far: 16,200 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:01:54
#
# 📦 Batch #163
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 16200
#    ├─ Total so far: 16,300 contacts
#    ├─ Speed: 141.9 contacts/sec
#    └─ Elapsed time: 0:01:54
#
# 📦 Batch #164
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 16300
#    ├─ Total so far: 16,400 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:01:55
#
# 📦 Batch #165
#    ├─ Retrieved: 100 contacts in 0.76s
#    ├─ Offset: 16400
#    ├─ Total so far: 16,500 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:01:56
#
# 📦 Batch #166
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 16500
#    ├─ Total so far: 16,600 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:01:57
#
# 📦 Batch #167
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 16600
#    ├─ Total so far: 16,700 contacts
#    ├─ Speed: 141.9 contacts/sec
#    └─ Elapsed time: 0:01:57
#
# 📦 Batch #168
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 16700
#    ├─ Total so far: 16,800 contacts
#    ├─ Speed: 141.9 contacts/sec
#    └─ Elapsed time: 0:01:58
#
# 📦 Batch #169
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 16800
#    ├─ Total so far: 16,900 contacts
#    ├─ Speed: 141.9 contacts/sec
#    └─ Elapsed time: 0:01:59
#
# 📦 Batch #170
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 16900
#    ├─ Total so far: 17,000 contacts
#    ├─ Speed: 141.9 contacts/sec
#    └─ Elapsed time: 0:01:59
#
# 📦 Batch #171
#    ├─ Retrieved: 100 contacts in 0.55s
#    ├─ Offset: 17000
#    ├─ Total so far: 17,100 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:00
#
# 📦 Batch #172
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 17100
#    ├─ Total so far: 17,200 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:01
#
# 📦 Batch #173
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 17200
#    ├─ Total so far: 17,300 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:01
#
# 📦 Batch #174
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 17300
#    ├─ Total so far: 17,400 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:02
#
# 📦 Batch #175
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 17400
#    ├─ Total so far: 17,500 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:03
#
# 📦 Batch #176
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 17500
#    ├─ Total so far: 17,600 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:03
#
# 📦 Batch #177
#    ├─ Retrieved: 100 contacts in 0.60s
#    ├─ Offset: 17600
#    ├─ Total so far: 17,700 contacts
#    ├─ Speed: 142.2 contacts/sec
#    └─ Elapsed time: 0:02:04
#
# 📦 Batch #178
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 17700
#    ├─ Total so far: 17,800 contacts
#    ├─ Speed: 142.3 contacts/sec
#    └─ Elapsed time: 0:02:05
#
# 📦 Batch #179
#    ├─ Retrieved: 100 contacts in 0.93s
#    ├─ Offset: 17800
#    ├─ Total so far: 17,900 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:06
#
# 📦 Batch #180
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 17900
#    ├─ Total so far: 18,000 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:06
#
# 📦 Batch #181
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 18000
#    ├─ Total so far: 18,100 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:07
#
# 📦 Batch #182
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 18100
#    ├─ Total so far: 18,200 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:08
#
# 📦 Batch #183
#    ├─ Retrieved: 100 contacts in 2.09s
#    ├─ Offset: 18200
#    ├─ Total so far: 18,300 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:10
#
# 📦 Batch #184
#    ├─ Retrieved: 100 contacts in 0.79s
#    ├─ Offset: 18300
#    ├─ Total so far: 18,400 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:11
#
# 📦 Batch #185
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 18400
#    ├─ Total so far: 18,500 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:11
#
# 📦 Batch #186
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 18500
#    ├─ Total so far: 18,600 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:12
#
# 📦 Batch #187
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 18600
#    ├─ Total so far: 18,700 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:13
#
# 📦 Batch #188
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 18700
#    ├─ Total so far: 18,800 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:02:13
#
# 📦 Batch #189
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 18800
#    ├─ Total so far: 18,900 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:02:14
#
# 📦 Batch #190
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 18900
#    ├─ Total so far: 19,000 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:02:15
#
# 📦 Batch #191
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 19000
#    ├─ Total so far: 19,100 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:15
#
# 📦 Batch #192
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 19100
#    ├─ Total so far: 19,200 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:16
#
# 📦 Batch #193
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 19200
#    ├─ Total so far: 19,300 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:17
#
# 📦 Batch #194
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 19300
#    ├─ Total so far: 19,400 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:02:17
#
# 📦 Batch #195
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 19400
#    ├─ Total so far: 19,500 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:02:18
#
# 📦 Batch #196
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 19500
#    ├─ Total so far: 19,600 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:02:19
#
# 📦 Batch #197
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 19600
#    ├─ Total so far: 19,700 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:02:20
#
# 📦 Batch #198
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 19700
#    ├─ Total so far: 19,800 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:02:20
#
# 📦 Batch #199
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 19800
#    ├─ Total so far: 19,900 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:02:21
#
# 📦 Batch #200
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 19900
#    ├─ Total so far: 20,000 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:02:22
#
# 📦 Batch #201
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 20000
#    ├─ Total so far: 20,100 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:02:22
#
# 📦 Batch #202
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 20100
#    ├─ Total so far: 20,200 contacts
#    ├─ Speed: 140.9 contacts/sec
#    └─ Elapsed time: 0:02:23
#
# 📦 Batch #203
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 20200
#    ├─ Total so far: 20,300 contacts
#    ├─ Speed: 140.9 contacts/sec
#    └─ Elapsed time: 0:02:24
#
# 📦 Batch #204
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 20300
#    ├─ Total so far: 20,400 contacts
#    ├─ Speed: 140.9 contacts/sec
#    └─ Elapsed time: 0:02:24
#
# 📦 Batch #205
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 20400
#    ├─ Total so far: 20,500 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:02:25
#
# 📦 Batch #206
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 20500
#    ├─ Total so far: 20,600 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:02:26
#
# 📦 Batch #207
#    ├─ Retrieved: 100 contacts in 0.79s
#    ├─ Offset: 20600
#    ├─ Total so far: 20,700 contacts
#    ├─ Speed: 140.9 contacts/sec
#    └─ Elapsed time: 0:02:26
#
# 📦 Batch #208
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 20700
#    ├─ Total so far: 20,800 contacts
#    ├─ Speed: 140.9 contacts/sec
#    └─ Elapsed time: 0:02:27
#
# 📦 Batch #209
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 20800
#    ├─ Total so far: 20,900 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:02:28
#
# 📦 Batch #210
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 20900
#    ├─ Total so far: 21,000 contacts
#    ├─ Speed: 141.0 contacts/sec
#    └─ Elapsed time: 0:02:28
#
# 📦 Batch #211
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 21000
#    ├─ Total so far: 21,100 contacts
#    ├─ Speed: 141.1 contacts/sec
#    └─ Elapsed time: 0:02:29
#
# 📦 Batch #212
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 21100
#    ├─ Total so far: 21,200 contacts
#    ├─ Speed: 141.1 contacts/sec
#    └─ Elapsed time: 0:02:30
#
# 📦 Batch #213
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 21200
#    ├─ Total so far: 21,300 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:02:30
#
# 📦 Batch #214
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 21300
#    ├─ Total so far: 21,400 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:02:31
#
# 📦 Batch #215
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 21400
#    ├─ Total so far: 21,500 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:02:32
#
# 📦 Batch #216
#    ├─ Retrieved: 100 contacts in 0.58s
#    ├─ Offset: 21500
#    ├─ Total so far: 21,600 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:02:32
#
# 📦 Batch #217
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 21600
#    ├─ Total so far: 21,700 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:02:33
#
# 📦 Batch #218
#    ├─ Retrieved: 100 contacts in 0.76s
#    ├─ Offset: 21700
#    ├─ Total so far: 21,800 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:02:34
#
# 📦 Batch #219
#    ├─ Retrieved: 100 contacts in 0.88s
#    ├─ Offset: 21800
#    ├─ Total so far: 21,900 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:02:35
#
# 📦 Batch #220
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 21900
#    ├─ Total so far: 22,000 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:02:35
#
# 📦 Batch #221
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 22000
#    ├─ Total so far: 22,100 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:02:36
#
# 📦 Batch #222
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 22100
#    ├─ Total so far: 22,200 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:02:37
#
# 📦 Batch #223
#    ├─ Retrieved: 100 contacts in 0.78s
#    ├─ Offset: 22200
#    ├─ Total so far: 22,300 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:02:37
#
# 📦 Batch #224
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 22300
#    ├─ Total so far: 22,400 contacts
#    ├─ Speed: 141.2 contacts/sec
#    └─ Elapsed time: 0:02:38
#
# 📦 Batch #225
#    ├─ Retrieved: 100 contacts in 0.57s
#    ├─ Offset: 22400
#    ├─ Total so far: 22,500 contacts
#    ├─ Speed: 141.3 contacts/sec
#    └─ Elapsed time: 0:02:39
#
# 📦 Batch #226
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 22500
#    ├─ Total so far: 22,600 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:02:39
#
# 📦 Batch #227
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 22600
#    ├─ Total so far: 22,700 contacts
#    ├─ Speed: 141.4 contacts/sec
#    └─ Elapsed time: 0:02:40
#
# 📦 Batch #228
#    ├─ Retrieved: 100 contacts in 0.59s
#    ├─ Offset: 22700
#    ├─ Total so far: 22,800 contacts
#    ├─ Speed: 141.5 contacts/sec
#    └─ Elapsed time: 0:02:41
#
# 📦 Batch #229
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 22800
#    ├─ Total so far: 22,900 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:02:41
#
# 📦 Batch #230
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 22900
#    ├─ Total so far: 23,000 contacts
#    ├─ Speed: 141.6 contacts/sec
#    └─ Elapsed time: 0:02:42
#
# 📦 Batch #231
#    ├─ Retrieved: 100 contacts in 0.53s
#    ├─ Offset: 23000
#    ├─ Total so far: 23,100 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:02:42
#
# 📦 Batch #232
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 23100
#    ├─ Total so far: 23,200 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:02:43
#
# 📦 Batch #233
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 23200
#    ├─ Total so far: 23,300 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:02:44
#
# 📦 Batch #234
#    ├─ Retrieved: 100 contacts in 0.57s
#    ├─ Offset: 23300
#    ├─ Total so far: 23,400 contacts
#    ├─ Speed: 141.9 contacts/sec
#    └─ Elapsed time: 0:02:44
#
# 📦 Batch #235
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 23400
#    ├─ Total so far: 23,500 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:45
#
# 📦 Batch #236
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 23500
#    ├─ Total so far: 23,600 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:46
#
# 📦 Batch #237
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 23600
#    ├─ Total so far: 23,700 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:46
#
# 📦 Batch #238
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 23700
#    ├─ Total so far: 23,800 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:47
#
# 📦 Batch #239
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 23800
#    ├─ Total so far: 23,900 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:48
#
# 📦 Batch #240
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 23900
#    ├─ Total so far: 24,000 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:48
#
# 📦 Batch #241
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 24000
#    ├─ Total so far: 24,100 contacts
#    ├─ Speed: 142.0 contacts/sec
#    └─ Elapsed time: 0:02:49
#
# 📦 Batch #242
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 24100
#    ├─ Total so far: 24,200 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:50
#
# 📦 Batch #243
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 24200
#    ├─ Total so far: 24,300 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:50
#
# 📦 Batch #244
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 24300
#    ├─ Total so far: 24,400 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:51
#
# 📦 Batch #245
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 24400
#    ├─ Total so far: 24,500 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:52
#
# 📦 Batch #246
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 24500
#    ├─ Total so far: 24,600 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:53
#
# 📦 Batch #247
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 24600
#    ├─ Total so far: 24,700 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:53
#
# 📦 Batch #248
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 24700
#    ├─ Total so far: 24,800 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:54
#
# 📦 Batch #249
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 24800
#    ├─ Total so far: 24,900 contacts
#    ├─ Speed: 142.2 contacts/sec
#    └─ Elapsed time: 0:02:55
#
# 📦 Batch #250
#    ├─ Retrieved: 100 contacts in 0.77s
#    ├─ Offset: 24900
#    ├─ Total so far: 25,000 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:55
#
# 📦 Batch #251
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 25000
#    ├─ Total so far: 25,100 contacts
#    ├─ Speed: 142.2 contacts/sec
#    └─ Elapsed time: 0:02:56
#
# 📦 Batch #252
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 25100
#    ├─ Total so far: 25,200 contacts
#    ├─ Speed: 142.2 contacts/sec
#    └─ Elapsed time: 0:02:57
#
# 📦 Batch #253
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 25200
#    ├─ Total so far: 25,300 contacts
#    ├─ Speed: 142.1 contacts/sec
#    └─ Elapsed time: 0:02:58
#
# 📦 Batch #254
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 25300
#    ├─ Total so far: 25,400 contacts
#    ├─ Speed: 142.2 contacts/sec
#    └─ Elapsed time: 0:02:58
#
# 📦 Batch #255
#    ├─ Retrieved: 100 contacts in 0.59s
#    ├─ Offset: 25400
#    ├─ Total so far: 25,500 contacts
#    ├─ Speed: 142.2 contacts/sec
#    └─ Elapsed time: 0:02:59
#
# 📦 Batch #256
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 25500
#    ├─ Total so far: 25,600 contacts
#    ├─ Speed: 142.3 contacts/sec
#    └─ Elapsed time: 0:02:59
#
# 📦 Batch #257
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 25600
#    ├─ Total so far: 25,700 contacts
#    ├─ Speed: 142.3 contacts/sec
#    └─ Elapsed time: 0:03:00
#
# 📦 Batch #258
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 25700
#    ├─ Total so far: 25,800 contacts
#    ├─ Speed: 142.4 contacts/sec
#    └─ Elapsed time: 0:03:01
#
# 📦 Batch #259
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 25800
#    ├─ Total so far: 25,900 contacts
#    ├─ Speed: 142.4 contacts/sec
#    └─ Elapsed time: 0:03:01
#
# 📦 Batch #260
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 25900
#    ├─ Total so far: 26,000 contacts
#    ├─ Speed: 142.4 contacts/sec
#    └─ Elapsed time: 0:03:02
#
# 📦 Batch #261
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 26000
#    ├─ Total so far: 26,100 contacts
#    ├─ Speed: 142.5 contacts/sec
#    └─ Elapsed time: 0:03:03
#
# 📦 Batch #262
#    ├─ Retrieved: 100 contacts in 0.64s
#    ├─ Offset: 26100
#    ├─ Total so far: 26,200 contacts
#    ├─ Speed: 142.5 contacts/sec
#    └─ Elapsed time: 0:03:03
#
# 📦 Batch #263
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 26200
#    ├─ Total so far: 26,300 contacts
#    ├─ Speed: 142.5 contacts/sec
#    └─ Elapsed time: 0:03:04
#
# 📦 Batch #264
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 26300
#    ├─ Total so far: 26,400 contacts
#    ├─ Speed: 142.5 contacts/sec
#    └─ Elapsed time: 0:03:05
#
# 📦 Batch #265
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 26400
#    ├─ Total so far: 26,500 contacts
#    ├─ Speed: 142.5 contacts/sec
#    └─ Elapsed time: 0:03:06
#
# 📦 Batch #266
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 26500
#    ├─ Total so far: 26,600 contacts
#    ├─ Speed: 142.5 contacts/sec
#    └─ Elapsed time: 0:03:06
#
# 📦 Batch #267
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 26600
#    ├─ Total so far: 26,700 contacts
#    ├─ Speed: 142.5 contacts/sec
#    └─ Elapsed time: 0:03:07
#
# 📦 Batch #268
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 26700
#    ├─ Total so far: 26,800 contacts
#    ├─ Speed: 142.6 contacts/sec
#    └─ Elapsed time: 0:03:07
#
# 📦 Batch #269
#    ├─ Retrieved: 100 contacts in 0.62s
#    ├─ Offset: 26800
#    ├─ Total so far: 26,900 contacts
#    ├─ Speed: 142.6 contacts/sec
#    └─ Elapsed time: 0:03:08
#
# 📦 Batch #270
#    ├─ Retrieved: 100 contacts in 2.00s
#    ├─ Offset: 26900
#    ├─ Total so far: 27,000 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:03:10
#
# 📦 Batch #271
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 27000
#    ├─ Total so far: 27,100 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:03:11
#
# 📦 Batch #272
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 27100
#    ├─ Total so far: 27,200 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:03:11
#
# 📦 Batch #273
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 27200
#    ├─ Total so far: 27,300 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:03:12
#
# 📦 Batch #274
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 27300
#    ├─ Total so far: 27,400 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:03:13
#
# 📦 Batch #275
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 27400
#    ├─ Total so far: 27,500 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:03:14
#
# 📦 Batch #276
#    ├─ Retrieved: 100 contacts in 0.56s
#    ├─ Offset: 27500
#    ├─ Total so far: 27,600 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:03:14
#
# 📦 Batch #277
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 27600
#    ├─ Total so far: 27,700 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:03:15
#
# 📦 Batch #278
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 27700
#    ├─ Total so far: 27,800 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:03:16
#
# 📦 Batch #279
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 27800
#    ├─ Total so far: 27,900 contacts
#    ├─ Speed: 141.7 contacts/sec
#    └─ Elapsed time: 0:03:16
#
# 📦 Batch #280
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 27900
#    ├─ Total so far: 28,000 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:03:17
#
# 📦 Batch #281
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 28000
#    ├─ Total so far: 28,100 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:03:18
#
# 📦 Batch #282
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 28100
#    ├─ Total so far: 28,200 contacts
#    ├─ Speed: 141.8 contacts/sec
#    └─ Elapsed time: 0:03:18
#
# 📦 Batch #283
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 28200
#    ├─ Total so far: 28,300 contacts
#    ├─ Speed: 141.9 contacts/sec
#    └─ Elapsed time: 0:03:19
#
# 📦 Batch #284
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 28300
#    ├─ Total so far: 28,400 contacts
#    ├─ Speed: 141.9 contacts/sec
#    └─ Elapsed time: 0:03:20
#
# 📦 Batch #285
#    ├─ Retrieved: 100 contacts in 0.63s
#    ├─ Offset: 28400
#    ├─ Total so far: 28,500 contacts
# ...
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:20:55
#
# 📦 Batch #1769
#    ├─ Retrieved: 100 contacts in 0.80s
#    ├─ Offset: 176800
#    ├─ Total so far: 176,900 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:20:56
#
# 📦 Batch #1770
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 176900
#    ├─ Total so far: 177,000 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:20:57
#
# 📦 Batch #1771
#    ├─ Retrieved: 100 contacts in 0.84s
#    ├─ Offset: 177000
#    ├─ Total so far: 177,100 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:20:57
#
# 📦 Batch #1772
#    ├─ Retrieved: 100 contacts in 0.85s
#    ├─ Offset: 177100
#    ├─ Total so far: 177,200 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:20:58
#
# 📦 Batch #1773
#    ├─ Retrieved: 100 contacts in 0.56s
#    ├─ Offset: 177200
#    ├─ Total so far: 177,300 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:20:59
#
# 📦 Batch #1774
#    ├─ Retrieved: 100 contacts in 0.85s
#    ├─ Offset: 177300
#    ├─ Total so far: 177,400 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:21:00
#
# 📦 Batch #1775
#    ├─ Retrieved: 100 contacts in 0.87s
#    ├─ Offset: 177400
#    ├─ Total so far: 177,500 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:01
#
# 📦 Batch #1776
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 177500
#    ├─ Total so far: 177,600 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:21:01
#
# 📦 Batch #1777
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 177600
#    ├─ Total so far: 177,700 contacts
#    ├─ Speed: 140.8 contacts/sec
#    └─ Elapsed time: 0:21:02
#
# 📦 Batch #1778
#    ├─ Retrieved: 100 contacts in 0.77s
#    ├─ Offset: 177700
#    ├─ Total so far: 177,800 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:03
#
# 📦 Batch #1779
#    ├─ Retrieved: 100 contacts in 0.66s
#    ├─ Offset: 177800
#    ├─ Total so far: 177,900 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:03
#
# 📦 Batch #1780
#    ├─ Retrieved: 100 contacts in 0.81s
#    ├─ Offset: 177900
#    ├─ Total so far: 178,000 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:04
#
# 📦 Batch #1781
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 178000
#    ├─ Total so far: 178,100 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:05
#
# 📦 Batch #1782
#    ├─ Retrieved: 100 contacts in 0.84s
#    ├─ Offset: 178100
#    ├─ Total so far: 178,200 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:06
#
# 📦 Batch #1783
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 178200
#    ├─ Total so far: 178,300 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:07
#
# 📦 Batch #1784
#    ├─ Retrieved: 100 contacts in 0.83s
#    ├─ Offset: 178300
#    ├─ Total so far: 178,400 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:07
#
# 📦 Batch #1785
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 178400
#    ├─ Total so far: 178,500 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:08
#
# 📦 Batch #1786
#    ├─ Retrieved: 100 contacts in 0.92s
#    ├─ Offset: 178500
#    ├─ Total so far: 178,600 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:09
#
# 📦 Batch #1787
#    ├─ Retrieved: 100 contacts in 0.84s
#    ├─ Offset: 178600
#    ├─ Total so far: 178,700 contacts
#    ├─ Speed: 140.7 contacts/sec
#    └─ Elapsed time: 0:21:10
#
# 📦 Batch #1788
#    ├─ Retrieved: 100 contacts in 0.87s
#    ├─ Offset: 178700
#    ├─ Total so far: 178,800 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:11
#
# 📦 Batch #1789
#    ├─ Retrieved: 100 contacts in 0.81s
#    ├─ Offset: 178800
#    ├─ Total so far: 178,900 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:12
#
# 📦 Batch #1790
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 178900
#    ├─ Total so far: 179,000 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:12
#
# 📦 Batch #1791
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 179000
#    ├─ Total so far: 179,100 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:13
#
# 📦 Batch #1792
#    ├─ Retrieved: 100 contacts in 0.80s
#    ├─ Offset: 179100
#    ├─ Total so far: 179,200 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:14
#
# 📦 Batch #1793
#    ├─ Retrieved: 100 contacts in 0.80s
#    ├─ Offset: 179200
#    ├─ Total so far: 179,300 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:15
#
# 📦 Batch #1794
#    ├─ Retrieved: 100 contacts in 0.82s
#    ├─ Offset: 179300
#    ├─ Total so far: 179,400 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:15
#
# 📦 Batch #1795
#    ├─ Retrieved: 100 contacts in 0.76s
#    ├─ Offset: 179400
#    ├─ Total so far: 179,500 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:16
#
# 📦 Batch #1796
#    ├─ Retrieved: 100 contacts in 0.77s
#    ├─ Offset: 179500
#    ├─ Total so far: 179,600 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:17
#
# 📦 Batch #1797
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 179600
#    ├─ Total so far: 179,700 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:18
#
# 📦 Batch #1798
#    ├─ Retrieved: 100 contacts in 0.78s
#    ├─ Offset: 179700
#    ├─ Total so far: 179,800 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:18
#
# 📦 Batch #1799
#    ├─ Retrieved: 100 contacts in 0.79s
#    ├─ Offset: 179800
#    ├─ Total so far: 179,900 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:19
#
# 📦 Batch #1800
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 179900
#    ├─ Total so far: 180,000 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:20
#
# 📦 Batch #1801
#    ├─ Retrieved: 100 contacts in 0.65s
#    ├─ Offset: 180000
#    ├─ Total so far: 180,100 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:21
#
# 📦 Batch #1802
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 180100
#    ├─ Total so far: 180,200 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:21
#
# 📦 Batch #1803
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 180200
#    ├─ Total so far: 180,300 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:22
#
# 📦 Batch #1804
#    ├─ Retrieved: 100 contacts in 0.83s
#    ├─ Offset: 180300
#    ├─ Total so far: 180,400 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:23
#
# 📦 Batch #1805
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 180400
#    ├─ Total so far: 180,500 contacts
#    ├─ Speed: 140.6 contacts/sec
#    └─ Elapsed time: 0:21:24
#
# 📦 Batch #1806
#    ├─ Retrieved: 100 contacts in 0.87s
#    ├─ Offset: 180500
#    ├─ Total so far: 180,600 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:25
#
# 📦 Batch #1807
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 180600
#    ├─ Total so far: 180,700 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:25
#
# 📦 Batch #1808
#    ├─ Retrieved: 100 contacts in 0.82s
#    ├─ Offset: 180700
#    ├─ Total so far: 180,800 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:26
#
# 📦 Batch #1809
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 180800
#    ├─ Total so far: 180,900 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:27
#
# 📦 Batch #1810
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 180900
#    ├─ Total so far: 181,000 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:28
#
# 📦 Batch #1811
#    ├─ Retrieved: 100 contacts in 0.86s
#    ├─ Offset: 181000
#    ├─ Total so far: 181,100 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:28
#
# 📦 Batch #1812
#    ├─ Retrieved: 100 contacts in 0.76s
#    ├─ Offset: 181100
#    ├─ Total so far: 181,200 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:29
#
# 📦 Batch #1813
#    ├─ Retrieved: 100 contacts in 0.81s
#    ├─ Offset: 181200
#    ├─ Total so far: 181,300 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:30
#
# 📦 Batch #1814
#    ├─ Retrieved: 100 contacts in 0.94s
#    ├─ Offset: 181300
#    ├─ Total so far: 181,400 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:31
#
# 📦 Batch #1815
#    ├─ Retrieved: 100 contacts in 0.79s
#    ├─ Offset: 181400
#    ├─ Total so far: 181,500 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:32
#
# 📦 Batch #1816
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 181500
#    ├─ Total so far: 181,600 contacts
#    ├─ Speed: 140.5 contacts/sec
#    └─ Elapsed time: 0:21:32
#
# 📦 Batch #1817
#    ├─ Retrieved: 100 contacts in 0.86s
#    ├─ Offset: 181600
#    ├─ Total so far: 181,700 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:33
#
# 📦 Batch #1818
#    ├─ Retrieved: 100 contacts in 0.83s
#    ├─ Offset: 181700
#    ├─ Total so far: 181,800 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:34
#
# 📦 Batch #1819
#    ├─ Retrieved: 100 contacts in 0.73s
#    ├─ Offset: 181800
#    ├─ Total so far: 181,900 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:35
#
# 📦 Batch #1820
#    ├─ Retrieved: 100 contacts in 1.16s
#    ├─ Offset: 181900
#    ├─ Total so far: 182,000 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:36
#
# 📦 Batch #1821
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 182000
#    ├─ Total so far: 182,100 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:37
#
# 📦 Batch #1822
#    ├─ Retrieved: 100 contacts in 0.67s
#    ├─ Offset: 182100
#    ├─ Total so far: 182,200 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:37
#
# 📦 Batch #1823
#    ├─ Retrieved: 100 contacts in 0.87s
#    ├─ Offset: 182200
#    ├─ Total so far: 182,300 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:38
#
# 📦 Batch #1824
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 182300
#    ├─ Total so far: 182,400 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:39
#
# 📦 Batch #1825
#    ├─ Retrieved: 100 contacts in 0.49s
#    ├─ Offset: 182400
#    ├─ Total so far: 182,500 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:40
#
# 📦 Batch #1826
#    ├─ Retrieved: 100 contacts in 0.93s
#    ├─ Offset: 182500
#    ├─ Total so far: 182,600 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:40
#
# 📦 Batch #1827
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 182600
#    ├─ Total so far: 182,700 contacts
#    ├─ Speed: 140.4 contacts/sec
#    └─ Elapsed time: 0:21:41
#
# 📦 Batch #1828
#    ├─ Retrieved: 100 contacts in 0.85s
#    ├─ Offset: 182700
#    ├─ Total so far: 182,800 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:42
#
# 📦 Batch #1829
#    ├─ Retrieved: 100 contacts in 0.74s
#    ├─ Offset: 182800
#    ├─ Total so far: 182,900 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:43
#
# 📦 Batch #1830
#    ├─ Retrieved: 100 contacts in 0.87s
#    ├─ Offset: 182900
#    ├─ Total so far: 183,000 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:44
#
# 📦 Batch #1831
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 183000
#    ├─ Total so far: 183,100 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:44
#
# 📦 Batch #1832
#    ├─ Retrieved: 100 contacts in 0.82s
#    ├─ Offset: 183100
#    ├─ Total so far: 183,200 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:45
#
# 📦 Batch #1833
#    ├─ Retrieved: 100 contacts in 1.04s
#    ├─ Offset: 183200
#    ├─ Total so far: 183,300 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:46
#
# 📦 Batch #1834
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 183300
#    ├─ Total so far: 183,400 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:47
#
# 📦 Batch #1835
#    ├─ Retrieved: 100 contacts in 0.85s
#    ├─ Offset: 183400
#    ├─ Total so far: 183,500 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:48
#
# 📦 Batch #1836
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 183500
#    ├─ Total so far: 183,600 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:48
#
# 📦 Batch #1837
#    ├─ Retrieved: 100 contacts in 0.69s
#    ├─ Offset: 183600
#    ├─ Total so far: 183,700 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:49
#
# 📦 Batch #1838
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 183700
#    ├─ Total so far: 183,800 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:50
#
# 📦 Batch #1839
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 183800
#    ├─ Total so far: 183,900 contacts
#    ├─ Speed: 140.3 contacts/sec
#    └─ Elapsed time: 0:21:51
#
# 📦 Batch #1840
#    ├─ Retrieved: 100 contacts in 0.87s
#    ├─ Offset: 183900
#    ├─ Total so far: 184,000 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:51
#
# 📦 Batch #1841
#    ├─ Retrieved: 100 contacts in 0.84s
#    ├─ Offset: 184000
#    ├─ Total so far: 184,100 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:52
#
# 📦 Batch #1842
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 184100
#    ├─ Total so far: 184,200 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:53
#
# 📦 Batch #1843
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 184200
#    ├─ Total so far: 184,300 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:54
#
# 📦 Batch #1844
#    ├─ Retrieved: 100 contacts in 0.88s
#    ├─ Offset: 184300
#    ├─ Total so far: 184,400 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:55
#
# 📦 Batch #1845
#    ├─ Retrieved: 100 contacts in 0.70s
#    ├─ Offset: 184400
#    ├─ Total so far: 184,500 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:55
#
# 📦 Batch #1846
#    ├─ Retrieved: 100 contacts in 0.87s
#    ├─ Offset: 184500
#    ├─ Total so far: 184,600 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:56
#
# 📦 Batch #1847
#    ├─ Retrieved: 100 contacts in 0.72s
#    ├─ Offset: 184600
#    ├─ Total so far: 184,700 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:57
#
# 📦 Batch #1848
#    ├─ Retrieved: 100 contacts in 0.75s
#    ├─ Offset: 184700
#    ├─ Total so far: 184,800 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:58
#
# 📦 Batch #1849
#    ├─ Retrieved: 100 contacts in 0.80s
#    ├─ Offset: 184800
#    ├─ Total so far: 184,900 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:58
#
# 📦 Batch #1850
#    ├─ Retrieved: 100 contacts in 0.76s
#    ├─ Offset: 184900
#    ├─ Total so far: 185,000 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:21:59
#
# 📦 Batch #1851
#    ├─ Retrieved: 100 contacts in 0.78s
#    ├─ Offset: 185000
#    ├─ Total so far: 185,100 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:22:00
#
# 📦 Batch #1852
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 185100
#    ├─ Total so far: 185,200 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:22:01
#
# 📦 Batch #1853
#    ├─ Retrieved: 100 contacts in 0.71s
#    ├─ Offset: 185200
#    ├─ Total so far: 185,300 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:22:01
#
# 📦 Batch #1854
#    ├─ Retrieved: 100 contacts in 0.68s
#    ├─ Offset: 185300
#    ├─ Total so far: 185,400 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:22:02
#
# 📦 Batch #1855
#    ├─ Retrieved: 100 contacts in 0.78s
#    ├─ Offset: 185400
#    ├─ Total so far: 185,500 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:22:03
#
# 📦 Batch #1856
#    ├─ Retrieved: 100 contacts in 0.78s
#    ├─ Offset: 185500
#    ├─ Total so far: 185,600 contacts
#    ├─ Speed: 140.2 contacts/sec
#    └─ Elapsed time: 0:22:04
#
# 📦 Batch #1857
#    ├─ Retrieved: 100 contacts in 0.88s
#    ├─ Offset: 185600
#    ├─ Total so far: 185,700 contacts
#    ├─ Speed: 140.1 contacts/sec
#    └─ Elapsed time: 0:22:05
#
# 📦 Batch #1858
#    ├─ Retrieved: 75 contacts in 0.73s
#    ├─ Offset: 185700
#    ├─ Total so far: 185,775 contacts
#    ├─ Speed: 140.1 contacts/sec
#    └─ Elapsed time: 0:22:05
#
# ✓ Reached end of contacts (last page).
#
# ================================================================================
# FETCH SUMMARY
# ================================================================================
# ✓ Total contacts retrieved: 185,775
# ✓ Total batches: 1858
# ✓ Total time: 0:22:05 (1325.81s)
# ✓ Average speed: 140.1 contacts/sec
# ✓ Batch size: 100
# ================================================================================

# %%
# Convert to DataFrame
if contacts:
    df = pd.DataFrame(contacts)
    
    print(f"DataFrame shape: {df.shape}")
    print(f"\nColumns: {list(df.columns)}")
    print(f"\nFirst few rows:")
    display(df.head())
    
    # Show data types
    print(f"\nData types:")
    print(df.dtypes)
    
    # Show basic statistics
    print(f"\nBasic info:")
    print(df.info())
    
else:
    print("No contacts found or error occurred.")
# Out:
# DataFrame shape: (185775, 42)
#
# Columns: ['cdate', 'email', 'phone', 'firstName', 'lastName', 'orgid', 'orgname', 'segmentio_id', 'bounced_hard', 'bounced_soft', 'bounced_date', 'ip', 'ua', 'hash', 'socialdata_lastcheck', 'email_local', 'email_domain', 'sentcnt', 'rating_tstamp', 'gravatar', 'deleted', 'anonymized', 'adate', 'udate', 'edate', 'deleted_at', 'created_utc_timestamp', 'updated_utc_timestamp', 'created_timestamp', 'updated_timestamp', 'created_by', 'updated_by', 'mpp_tracking', 'last_click_date', 'last_open_date', 'last_mpp_open_date', 'best_send_hour', 'scoreValues', 'accountContacts', 'links', 'id', 'organization']
#
# First few rows:
#                        cdate                        email          phone  \
# 0  2024-12-17T09:10:40-06:00                         None  +447971166835
# 1  2022-06-09T12:55:11-05:00   0.hominy.module@icloud.com
# 2  2022-06-13T17:26:28-05:00      0.xstriderx.0@gmail.com
# 3  2023-04-08T14:37:32-05:00  00.ogress-shreds@icloud.com
# 4  2024-01-09T21:21:17-06:00            0001dws@gmail.com
#
#   firstName lastName orgid orgname segmentio_id bounced_hard bounced_soft  \
# 0   Anthony     Kemp     0                                 0            0
# 1     Simon   Little     0                                 0            0
# 2                        0                                 0            0
# 3                        0                                 0            0
# 4     David  Shirley     0                                 0            0
#
#    ... mpp_tracking      last_click_date       last_open_date  \
# 0  ...            0                 None                 None
# 1  ...            1  2023-02-17 16:44:14  2023-02-17 16:44:14
# 2  ...            0                 None  2023-05-18 05:59:06
# 3  ...            0  2023-05-02 09:58:48  2023-05-23 04:13:14
# 4  ...            0                 None                 None
#
#     last_mpp_open_date best_send_hour       scoreValues accountContacts  \
# 0                 None              0  [338356, 338387]              []
# 1  2023-02-17 16:44:26              0    [48566, 50532]              []
# 2                 None              0  [188178, 188199]              []
# 3  2023-05-23 04:13:03              0  [267408, 267509]              []
# 4                 None           None  [299054, 299083]              []
#
#                                                links      id organization
# 0  {'bounceLogs': 'https://ehb.api-us1.com/api/3/...  169196         None
# 1  {'bounceLogs': 'https://ehb.api-us1.com/api/3/...   24656         None
# 2  {'bounceLogs': 'https://ehb.api-us1.com/api/3/...   94097         None
# 3  {'bounceLogs': 'https://ehb.api-us1.com/api/3/...  133722         None
# 4  {'bounceLogs': 'https://ehb.api-us1.com/api/3/...  149539         None
#
# [5 rows x 42 columns]
# Data types:
# cdate                    object
# email                    object
# phone                    object
# firstName                object
# lastName                 object
# orgid                    object
# orgname                  object
# segmentio_id             object
# bounced_hard             object
# bounced_soft             object
# bounced_date             object
# ip                       object
# ua                       object
# hash                     object
# socialdata_lastcheck     object
# email_local              object
# email_domain             object
# sentcnt                  object
# rating_tstamp            object
# gravatar                 object
# deleted                  object
# anonymized               object
# adate                    object
# udate                    object
# edate                    object
# deleted_at               object
# created_utc_timestamp    object
# updated_utc_timestamp    object
# created_timestamp        object
# updated_timestamp        object
# created_by               object
# updated_by               object
# mpp_tracking             object
# last_click_date          object
# last_open_date           object
# last_mpp_open_date       object
# best_send_hour           object
# scoreValues              object
# accountContacts          object
# links                    object
# id                       object
# organization             object
# dtype: object
#
# Basic info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185775 entries, 0 to 185774
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   cdate                  185775 non-null  object
#  1   email                  185774 non-null  object
#  2   phone                  185775 non-null  object
#  3   firstName              185775 non-null  object
#  4   lastName               185775 non-null  object
#  5   orgid                  185775 non-null  object
#  6   orgname                185775 non-null  object
#  7   segmentio_id           185775 non-null  object
#  8   bounced_hard           185775 non-null  object
#  9   bounced_soft           185775 non-null  object
#  10  bounced_date           11920 non-null   object
#  11  ip                     185775 non-null  object
#  12  ua                     90918 non-null   object
#  13  hash                   185775 non-null  object
#  14  socialdata_lastcheck   0 non-null       object
#  15  email_local            185775 non-null  object
#  16  email_domain           185775 non-null  object
#  17  sentcnt                185775 non-null  object
#  18  rating_tstamp          91268 non-null   object
#  19  gravatar               185775 non-null  object
#  20  deleted                185775 non-null  object
#  21  anonymized             185775 non-null  object
#  22  adate                  1376 non-null    object
#  23  udate                  185775 non-null  object
#  24  edate                  1295 non-null    object
#  25  deleted_at             0 non-null       object
#  26  created_utc_timestamp  185775 non-null  object
#  27  updated_utc_timestamp  185775 non-null  object
#  28  created_timestamp      185775 non-null  object
#  29  updated_timestamp      185775 non-null  object
#  30  created_by             79268 non-null   object
#  31  updated_by             79268 non-null   object
#  32  mpp_tracking           185775 non-null  object
#  33  last_click_date        43698 non-null   object
#  34  last_open_date         91268 non-null   object
#  35  last_mpp_open_date     63704 non-null   object
#  36  best_send_hour         13791 non-null   object
#  37  scoreValues            185775 non-null  object
#  38  accountContacts        185775 non-null  object
#  39  links                  185775 non-null  object
#  40  id                     185775 non-null  object
#  41  organization           1324 non-null    object
# dtypes: object(42)
# memory usage: 59.5+ MB
# None

# %%
# Now you can work with the df DataFrame
# It contains all contacts with all available datapoints
# All operations here are local - nothing will be sent to ActiveCampaign

print("\n=== DataFrame is ready for analysis ===")
print(f"Variable 'df' contains {len(df)} contacts")
print(f"All {len(df.columns)} columns/datapoints are available")
print("\nYou can now analyze the data using pandas operations.")
# Out:
# === DataFrame is ready for analysis ===
# Variable 'df' contains 185775 contacts
# All 42 columns/datapoints are available
#
# You can now analyze the data using pandas operations.

# %% [markdown]
# ## Filter: Contacts with Only Email (No Lists)

# %%
# Filter contacts: No lists + Only email data
# Uses df_enriched which has all the data we fetched

print("\n" + "=" * 80)
print("FILTERING: Contacts with NO Lists + ONLY Email Data")
print("=" * 80)

# Filter 1: No list subscriptions (using the has_any_lists flag)
df_no_lists = df_enriched[~df_enriched['has_any_lists']].copy()
print(f"✓ Contacts with NO list subscriptions: {len(df_no_lists):,}")

# Filter 2: Only email is filled (all other meaningful fields are empty)
# Define meaningful data fields (excluding technical/system fields)
data_fields = ['firstName', 'lastName', 'phone', 'address1', 'address2', 'city', 
               'state', 'zip', 'country', 'organization']

# Find which fields exist in our DataFrame
existing_data_fields = [f for f in data_fields if f in df_no_lists.columns]
print(f"✓ Checking these data fields: {existing_data_fields}")

# Function to check if only email has data
def has_only_email(row):
    """Check if only email has data, all other fields are empty"""
    for field in existing_data_fields:
        value = row.get(field, None)
        # Check if field has meaningful data (not empty, not null, not just whitespace)
        if pd.notna(value) and str(value).strip() != '':
            return False
    
    # Also check if they have tags, deals, or automations
    if row.get('tag_count', 0) > 0:
        return False
    if row.get('deal_count', 0) > 0:
        return False
    
    return True

# Apply the filter
email_only_contacts = df_no_lists[df_no_lists.apply(has_only_email, axis=1)].copy()

print(f"\n" + "=" * 80)
print("FILTER RESULTS")
print("=" * 80)
print(f"✓ Contacts with NO list subscriptions: {len(df_no_lists):,}")
print(f"✓ Contacts with ONLY email (no other data): {len(email_only_contacts):,}")
print(f"✓ Percentage of total: {(len(email_only_contacts)/len(df_enriched)*100):.2f}%")
print("=" * 80)

# Show sample of results
if not email_only_contacts.empty:
    print(f"\n📋 Sample of email-only contacts (first 20):")
    display_cols = ['id', 'email', 'list_count', 'tag_count', 'deal_count'] + existing_data_fields
    display_cols = [c for c in display_cols if c in email_only_contacts.columns]
    display(email_only_contacts[display_cols].head(20))
    
    # Create a simple list of emails
    email_only_list = email_only_contacts['email'].tolist()
    
    print(f"\n✓ Created 'email_only_contacts' DataFrame with {len(email_only_contacts):,} contacts")
    print(f"✓ Created 'email_only_list' with {len(email_only_list):,} email addresses")
    print(f"\nTo see all emails: print(email_only_list)")
else:
    print("\n⚠️  No contacts found matching criteria (no lists + only email)")
# Out:
# ================================================================================
# FILTERING CONTACTS: No Lists + Only Email
# ================================================================================
#
# 📊 DataFrame Overview:
# Total contacts: 185,775
# Total columns: 42
#
# Column names:
#   - cdate
#   - email
#   - phone
#   - firstName
#   - lastName
#   - orgid
#   - orgname
#   - segmentio_id
#   - bounced_hard
#   - bounced_soft
#   - bounced_date
#   - ip
#   - ua
#   - hash
#   - socialdata_lastcheck
#   - email_local
#   - email_domain
#   - sentcnt
#   - rating_tstamp
#   - gravatar
#   - deleted
#   - anonymized
#   - adate
#   - udate
#   - edate
#   - deleted_at
#   - created_utc_timestamp
#   - updated_utc_timestamp
#   - created_timestamp
#   - updated_timestamp
#   - created_by
#   - updated_by
#   - mpp_tracking
#   - last_click_date
#   - last_open_date
#   - last_mpp_open_date
#   - best_send_hour
#   - scoreValues
#   - accountContacts
#   - links
#   - id
#   - organization
#
# 📋 List-related columns found: []
#
# ✓ Contacts with no list subscriptions: 0
#
# 📝 Checking these data fields: ['firstName', 'lastName', 'phone', 'organization']
#
# ================================================================================
# RESULTS
# ================================================================================
# ✓ Contacts with NO list subscriptions: 0
# ✓ Contacts with ONLY email data: 0
# ✓ Percentage of total: 0.00%
# ================================================================================
#
# 📋 Sample of email-only contacts (first 10):
# No contacts found matching criteria.

# %% [markdown]
# ## All Columns Analysis

# %%
# Show all columns with detailed information
print("=" * 100)
print("ALL COLUMNS IN DATAFRAME")
print("=" * 100)

print(f"\nTotal columns: {len(df.columns)}")
print(f"Total rows: {len(df):,}")

print("\n" + "=" * 100)
print("COLUMN DETAILS")
print("=" * 100)

for i, col in enumerate(df.columns, 1):
    print(f"\n{i:2d}. Column: '{col}'")
    print(f"    Type: {df[col].dtype}")
    print(f"    Non-null count: {df[col].notna().sum():,} / {len(df):,} ({(df[col].notna().sum()/len(df)*100):.1f}%)")
    
    # Show unique values count (handle unhashable types)
    try:
        unique_count = df[col].nunique()
        print(f"    Unique values: {unique_count:,}")
    except TypeError as e:
        print(f"    Unique values: Cannot calculate (contains unhashable types like lists)")
    
    # Show sample values (non-null)
    non_null_values = df[col].dropna()
    if len(non_null_values) > 0:
        print(f"    Sample values:")
        sample_values = non_null_values.head(5).tolist()
        for val in sample_values:
            # Handle different data types
            if isinstance(val, (list, dict)):
                val_str = f"{type(val).__name__}: {str(val)[:50]}..."
            else:
                val_str = str(val)
                if len(val_str) > 50:
                    val_str = val_str[:47] + "..."
            print(f"      - {val_str}")
        
        if len(non_null_values) > 5:
            print(f"      ... and {len(non_null_values) - 5} more")
    else:
        print(f"    All values are null/empty")

print("\n" + "=" * 100)
print("QUICK REFERENCE - COLUMN NAMES")
print("=" * 100)

for i, col in enumerate(df.columns, 1):
    print(f"{i:2d}. {col}")

print(f"\nTotal: {len(df.columns)} columns")
# Out:
# ====================================================================================================
# ALL COLUMNS IN DATAFRAME
# ====================================================================================================
#
# Total columns: 42
# Total rows: 185,775
#
# ====================================================================================================
# COLUMN DETAILS
# ====================================================================================================
#
#  1. Column: 'cdate'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 84,152
#     Sample values:
#       - 2024-12-17T09:10:40-06:00
#       - 2022-06-09T12:55:11-05:00
#       - 2022-06-13T17:26:28-05:00
#       - 2023-04-08T14:37:32-05:00
#       - 2024-01-09T21:21:17-06:00
#       ... and 185770 more
#
#  2. Column: 'email'
#     Type: object
#     Non-null count: 185,774 / 185,775 (100.0%)
#     Unique values: 185,774
#     Sample values:
#       - 0.hominy.module@icloud.com
#       - 0.xstriderx.0@gmail.com
#       - 00.ogress-shreds@icloud.com
#       - 0001dws@gmail.com
#       - 0002@imagens.cf
#       ... and 185769 more
#
#  3. Column: 'phone'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 43,351
#     Sample values:
#       - +447971166835
#       -
#       -
#       -
#       -
#       ... and 185770 more
#
#  4. Column: 'firstName'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 26,973
#     Sample values:
#       - Anthony
#       - Simon
#       -
#       -
#       - David
#       ... and 185770 more
#
#  5. Column: 'lastName'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 44,563
#     Sample values:
#       - Kemp
#       - Little
#       -
#       -
#       - Shirley
#       ... and 185770 more
#
#  6. Column: 'orgid'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 1,223
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 185770 more
#
#  7. Column: 'orgname'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 1,223
#     Sample values:
#       -
#       -
#       -
#       -
#       -
#       ... and 185770 more
#
#  8. Column: 'segmentio_id'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 1
#     Sample values:
#       -
#       -
#       -
#       -
#       -
#       ... and 185770 more
#
#  9. Column: 'bounced_hard'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 5
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 185770 more
#
# 10. Column: 'bounced_soft'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 6
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 185770 more
#
# 11. Column: 'bounced_date'
#     Type: object
#     Non-null count: 11,920 / 185,775 (6.4%)
#     Unique values: 436
#     Sample values:
#       - 2022-07-28
#       - 2022-08-04
#       - 2023-05-09
#       - 2022-07-13
#       - 2022-12-26
#       ... and 11915 more
#
# 12. Column: 'ip'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 38,175
#     Sample values:
#       - 0
#       - 585756439
#       - 872557533
#       - 64811981
#       - 0
#       ... and 185770 more
#
# 13. Column: 'ua'
#     Type: object
#     Non-null count: 90,918 / 185,775 (48.9%)
#     Unique values: 213
#     Sample values:
#       -
#       - Mozilla/5.0
#       - okhttp/3.14.1
#       -
#       -
#       ... and 90913 more
#
# 14. Column: 'hash'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 185,775
#     Sample values:
#       - 9442c41a31d3aad140c00ed21073095b
#       - 6bd604db025894b6980d8b30d8a7bd89
#       - c1fb1ab4d583959432f870e0014ef81e
#       - bc013ef997d7250c26757d3fb07514b6
#       - bed7b44265c7bf16192fb5ff635a39a7
#       ... and 185770 more
#
# 15. Column: 'socialdata_lastcheck'
#     Type: object
#     Non-null count: 0 / 185,775 (0.0%)
#     Unique values: 0
#     All values are null/empty
#
# 16. Column: 'email_local'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 1
#     Sample values:
#       -
#       -
#       -
#       -
#       -
#       ... and 185770 more
#
# 17. Column: 'email_domain'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 26,814
#     Sample values:
#       -
#       - icloud.com
#       - gmail.com
#       - icloud.com
#       - gmail.com
#       ... and 185770 more
#
# 18. Column: 'sentcnt'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 139
#     Sample values:
#       - 0
#       - 6
#       - 8
#       - 5
#       - 0
#       ... and 185770 more
#
# 19. Column: 'rating_tstamp'
#     Type: object
#     Non-null count: 91,268 / 185,775 (49.1%)
#     Unique values: 1,210
#     Sample values:
#       - 2022-11-08
#       - 2023-05-18
#       - 2023-05-23
#       - 2024-09-16
#       - 2023-03-31
#       ... and 91263 more
#
# 20. Column: 'gravatar'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 3
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 185770 more
#
# 21. Column: 'deleted'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 1
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 185770 more
#
# 22. Column: 'anonymized'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 1
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 185770 more
#
# 23. Column: 'adate'
#     Type: object
#     Non-null count: 1,376 / 185,775 (0.7%)
#     Unique values: 1,374
#     Sample values:
#       - 2025-10-21T04:54:22-05:00
#       - 2025-06-11T07:09:00-05:00
#       - 2025-10-21T04:54:44-05:00
#       - 2025-10-21T04:55:02-05:00
#       - 2024-12-15T11:56:30-06:00
#       ... and 1371 more
#
# 24. Column: 'udate'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 47,919
#     Sample values:
#       - 2025-10-08T12:58:45-05:00
#       - 2023-02-03T09:27:35-06:00
#       - 2023-08-23T05:59:11-05:00
#       - 2025-08-27T08:19:41-05:00
#       - 2024-12-17T09:57:41-06:00
#       ... and 185770 more
#
# 25. Column: 'edate'
#     Type: object
#     Non-null count: 1,295 / 185,775 (0.7%)
#     Unique values: 1,295
#     Sample values:
#       - 2025-10-21T04:54:15-05:00
#       - 2025-06-11T06:51:37-05:00
#       - 2025-10-21T04:54:30-05:00
#       - 2025-10-21T04:54:49-05:00
#       - 2024-12-15T11:56:25-06:00
#       ... and 1290 more
#
# 26. Column: 'deleted_at'
#     Type: object
#     Non-null count: 0 / 185,775 (0.0%)
#     Unique values: 0
#     All values are null/empty
#
# 27. Column: 'created_utc_timestamp'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 84,152
#     Sample values:
#       - 2024-12-17 09:10:40
#       - 2022-06-09 12:55:11
#       - 2022-06-13 17:26:28
#       - 2023-04-08 14:37:32
#       - 2024-01-09 21:21:17
#       ... and 185770 more
#
# 28. Column: 'updated_utc_timestamp'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 43,619
#     Sample values:
#       - 2025-10-21 04:54:15
#       - 2025-06-11 06:51:37
#       - 2025-10-21 04:54:30
#       - 2025-10-21 04:54:49
#       - 2024-12-17 09:57:41
#       ... and 185770 more
#
# 29. Column: 'created_timestamp'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 84,152
#     Sample values:
#       - 2024-12-17 09:10:40
#       - 2022-06-09 12:55:11
#       - 2022-06-13 17:26:28
#       - 2023-04-08 14:37:32
#       - 2024-01-09 21:21:17
#       ... and 185770 more
#
# 30. Column: 'updated_timestamp'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 43,619
#     Sample values:
#       - 2025-10-21 04:54:15
#       - 2025-06-11 06:51:37
#       - 2025-10-21 04:54:30
#       - 2025-10-21 04:54:49
#       - 2024-12-17 09:57:41
#       ... and 185770 more
#
# 31. Column: 'created_by'
#     Type: object
#     Non-null count: 79,268 / 185,775 (42.7%)
#     Unique values: 1
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 79263 more
#
# 32. Column: 'updated_by'
#     Type: object
#     Non-null count: 79,268 / 185,775 (42.7%)
#     Unique values: 1
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 79263 more
#
# 33. Column: 'mpp_tracking'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 2
#     Sample values:
#       - 0
#       - 1
#       - 0
#       - 0
#       - 0
#       ... and 185770 more
#
# 34. Column: 'last_click_date'
#     Type: object
#     Non-null count: 43,698 / 185,775 (23.5%)
#     Unique values: 36,015
#     Sample values:
#       - 2023-02-17 16:44:14
#       - 2023-05-02 09:58:48
#       - 2023-02-17 16:44:17
#       - 2025-07-17 03:47:45
#       - 2023-06-02 04:55:19
#       ... and 43693 more
#
# 35. Column: 'last_open_date'
#     Type: object
#     Non-null count: 91,268 / 185,775 (49.1%)
#     Unique values: 79,988
#     Sample values:
#       - 2023-02-17 16:44:14
#       - 2023-05-18 05:59:06
#       - 2023-05-23 04:13:14
#       - 2024-09-16 14:35:36
#       - 2023-03-31 04:52:45
#       ... and 91263 more
#
# 36. Column: 'last_mpp_open_date'
#     Type: object
#     Non-null count: 63,704 / 185,775 (34.3%)
#     Unique values: 59,311
#     Sample values:
#       - 2023-02-17 16:44:26
#       - 2023-05-23 04:13:03
#       - 2023-03-31 04:52:21
#       - 2025-09-04 03:48:38
#       - 2025-06-27 00:49:12
#       ... and 63699 more
#
# 37. Column: 'best_send_hour'
#     Type: object
#     Non-null count: 13,791 / 185,775 (7.4%)
#     Unique values: 1
#     Sample values:
#       - 0
#       - 0
#       - 0
#       - 0
#       - 0
#       ... and 13786 more
#
# 38. Column: 'scoreValues'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: Cannot calculate (contains unhashable types like lists)
#     Sample values:
#       - list: ['338356', '338387']...
#       - list: ['48566', '50532']...
#       - list: ['188178', '188199']...
#       - list: ['267408', '267509']...
#       - list: ['299054', '299083']...
#       ... and 185770 more
#
# 39. Column: 'accountContacts'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: Cannot calculate (contains unhashable types like lists)
#     Sample values:
#       - list: []...
#       - list: []...
#       - list: []...
#       - list: []...
#       - list: []...
#       ... and 185770 more
#
# 40. Column: 'links'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: Cannot calculate (contains unhashable types like lists)
#     Sample values:
#       - dict: {'bounceLogs': 'https://ehb.api-us1.com/api/3/cont...
#       - dict: {'bounceLogs': 'https://ehb.api-us1.com/api/3/cont...
#       - dict: {'bounceLogs': 'https://ehb.api-us1.com/api/3/cont...
#       - dict: {'bounceLogs': 'https://ehb.api-us1.com/api/3/cont...
#       - dict: {'bounceLogs': 'https://ehb.api-us1.com/api/3/cont...
#       ... and 185770 more
#
# 41. Column: 'id'
#     Type: object
#     Non-null count: 185,775 / 185,775 (100.0%)
#     Unique values: 185,775
#     Sample values:
#       - 169196
#       - 24656
#       - 94097
#       - 133722
#       - 149539
#       ... and 185770 more
#
# 42. Column: 'organization'
#     Type: object
#     Non-null count: 1,324 / 185,775 (0.7%)
#     Unique values: 1,222
#     Sample values:
#       - 789
#       - 536
#       - 824
#       - 271
#       - 455
#       ... and 1319 more
#
# ====================================================================================================
# QUICK REFERENCE - COLUMN NAMES
# ====================================================================================================
#  1. cdate
#  2. email
#  3. phone
#  4. firstName
#  5. lastName
#  6. orgid
#  7. orgname
#  8. segmentio_id
#  9. bounced_hard
# 10. bounced_soft
# 11. bounced_date
# 12. ip
# 13. ua
# 14. hash
# 15. socialdata_lastcheck
# 16. email_local
# 17. email_domain
# 18. sentcnt
# 19. rating_tstamp
# 20. gravatar
# 21. deleted
# 22. anonymized
# 23. adate
# 24. udate
# 25. edate
# 26. deleted_at
# 27. created_utc_timestamp
# 28. updated_utc_timestamp
# 29. created_timestamp
# 30. updated_timestamp
# 31. created_by
# 32. updated_by
# 33. mpp_tracking
# 34. last_click_date
# 35. last_open_date
# 36. last_mpp_open_date
# 37. best_send_hour
# 38. scoreValues
# 39. accountContacts
# 40. links
# 41. id
# 42. organization
#
# Total: 42 columns

# %% [markdown]
# ## Get List Memberships for All Contacts

# %%
# Fetch ALL additional data for each contact
# This includes: list memberships, tags, deals, and any other available data

def get_contact_additional_data(contact_id: str, api_url: str, headers: Dict[str, str]) -> Dict[str, Any]:
    """
    Get all additional data for a contact (READ ONLY).
    Returns: dict with lists, tags, deals, etc.
    """
    additional_data = {
        'lists': [],
        'tags': [],
        'deals': [],
        'contactAutomations': []
    }
    
    # 1. Get list memberships
    try:
        url = f"{api_url}/api/3/contacts/{contact_id}/contactLists"
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            additional_data['lists'] = data.get('contactLists', [])
    except:
        pass
    
    # 2. Get tags
    try:
        url = f"{api_url}/api/3/contacts/{contact_id}/contactTags"
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            additional_data['tags'] = data.get('contactTags', [])
    except:
        pass
    
    # 3. Get deals
    try:
        url = f"{api_url}/api/3/contacts/{contact_id}/deals"
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            additional_data['deals'] = data.get('deals', [])
    except:
        pass
    
    # 4. Get contact automations
    try:
        url = f"{api_url}/api/3/contacts/{contact_id}/contactAutomations"
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            additional_data['contactAutomations'] = data.get('contactAutomations', [])
    except:
        pass
    
    return additional_data

# Fetch additional data for all contacts
print("\n" + "=" * 80)
print("FETCHING ADDITIONAL DATA FOR ALL CONTACTS (Lists, Tags, Deals, etc.)")
print("=" * 80)
print("⚠️  This may take a while depending on the number of contacts...")

start_time = time.time()
enriched_contacts = []
total_contacts = len(df)

for idx, contact_row in df.iterrows():
    contact_id = contact_row['id']
    
    # Get base contact data
    contact_data = contact_row.to_dict()
    
    # Get additional data
    additional = get_contact_additional_data(contact_id, API_URL, headers)
    
    # Add additional data to contact
    contact_data['list_memberships'] = additional['lists']
    contact_data['tags'] = additional['tags']
    contact_data['deals'] = additional['deals']
    contact_data['automations'] = additional['contactAutomations']
    
    # Calculate derived fields
    contact_data['list_count'] = len(additional['lists'])
    contact_data['tag_count'] = len(additional['tags'])
    contact_data['deal_count'] = len(additional['deals'])
    contact_data['automation_count'] = len(additional['contactAutomations'])
    contact_data['has_any_lists'] = len(additional['lists']) > 0
    
    # Extract list IDs for easy filtering
    contact_data['list_ids'] = [l.get('list') for l in additional['lists']]
    contact_data['tag_ids'] = [t.get('tag') for t in additional['tags']]
    
    enriched_contacts.append(contact_data)
    
    # Progress updates
    processed = idx + 1
    if processed % 10 == 0:
        elapsed = time.time() - start_time
        rate = processed / elapsed
        remaining = (total_contacts - processed) / rate if rate > 0 else 0
        print(f"Progress: {processed}/{total_contacts} ({(processed/total_contacts*100):.1f}%) | "
              f"Speed: {rate:.1f} contacts/sec | "
              f"ETA: {timedelta(seconds=int(remaining))}")

# Create enriched DataFrame
df_enriched = pd.DataFrame(enriched_contacts)

total_time = time.time() - start_time
print("\n" + "=" * 80)
print("ENRICHMENT COMPLETE")
print("=" * 80)
print(f"✓ Total contacts enriched: {len(df_enriched):,}")
print(f"✓ Total time: {timedelta(seconds=int(total_time))} ({total_time:.2f}s)")
print(f"✓ Average speed: {len(df_enriched)/total_time:.1f} contacts/sec")
print(f"\n📊 SUMMARY:")
print(f"   ├─ Contacts with list memberships: {df_enriched['has_any_lists'].sum():,}")
print(f"   ├─ Contacts without any lists: {(~df_enriched['has_any_lists']).sum():,}")
print(f"   ├─ Contacts with tags: {(df_enriched['tag_count'] > 0).sum():,}")
print(f"   ├─ Contacts with deals: {(df_enriched['deal_count'] > 0).sum():,}")
print(f"   └─ Contacts in automations: {(df_enriched['automation_count'] > 0).sum():,}")
print("=" * 80)
print(f"\n✓ Created 'df_enriched' DataFrame with ALL contact data")
# Out:
# ================================================================================
# FETCHING ADDITIONAL DATA FOR ALL CONTACTS (Lists, Tags, Deals, etc.)
# ================================================================================
# ⚠️  This may take a while depending on the number of contacts...
# Progress: 10/185775 (0.0%) | Speed: 0.6 contacts/sec | ETA: 3 days, 9:05:40
# Progress: 20/185775 (0.0%) | Speed: 0.6 contacts/sec | ETA: 3 days, 11:25:37

# %% [markdown]
# ## Filter: Contacts with Age Data

# %%
# Find contacts that have age data filled
print("\n" + "=" * 80)
print("FILTERING: Contacts with Age Data")
print("=" * 80)

# First, let's check what age-related columns exist
age_columns = [col for col in df_enriched.columns if 'age' in col.lower()]
print(f"✓ Age-related columns found: {age_columns}")

# Check if we have custom field values that might contain age
if 'fieldValues' in df_enriched.columns:
    print(f"\n📊 Checking fieldValues for age data...")
    # Look at sample fieldValues to understand structure
    sample_field_values = df_enriched['fieldValues'].dropna().head(5)
    for idx, fv in sample_field_values.items():
        print(f"Sample {idx}: {fv}")

# Look for age in custom fields (fieldValues)
contacts_with_age = df_enriched.copy()

# Method 1: Check if 'Age' appears in fieldValues
if 'fieldValues' in df_enriched.columns:
    def has_age_in_fields(field_values):
        if pd.isna(field_values):
            return False
        # Convert to string and check for age-related content
        field_str = str(field_values).lower()
        return 'age' in field_str or any(age_term in field_str for age_term in ['18-24', '25-34', '35-44', '45-54', '55-64', '65+'])
    
    contacts_with_age['has_age_field'] = contacts_with_age['fieldValues'].apply(has_age_in_fields)
    age_from_fields = contacts_with_age['has_age_field'].sum()
    print(f"✓ Contacts with age in fieldValues: {age_from_fields:,}")
else:
    contacts_with_age['has_age_field'] = False
    age_from_fields = 0

# Method 2: Check direct age columns
age_direct = 0
for col in age_columns:
    if col in df_enriched.columns:
        non_null_count = df_enriched[col].notna().sum()
        print(f"✓ Column '{col}' has {non_null_count:,} non-null values")
        age_direct += non_null_count

# Method 3: Check if any contact has age data in any form
def has_any_age_data(row):
    # Check direct age columns
    for col in age_columns:
        if col in df_enriched.columns and pd.notna(row[col]) and str(row[col]).strip() != '':
            return True
    
    # Check fieldValues
    if 'fieldValues' in df_enriched.columns and pd.notna(row['fieldValues']):
        field_str = str(row['fieldValues']).lower()
        if 'age' in field_str or any(age_term in field_str for age_term in ['18-24', '25-34', '35-44', '45-54', '55-64', '65+']):
            return True
    
    return False

contacts_with_age['has_any_age'] = contacts_with_age.apply(has_any_age_data, axis=1)
total_with_age = contacts_with_age['has_any_age'].sum()

print(f"\n" + "=" * 80)
print("AGE DATA SUMMARY")
print("=" * 80)
print(f"✓ Total contacts: {len(df_enriched):,}")
print(f"✓ Contacts with age data: {total_with_age:,}")
print(f"✓ Percentage with age: {(total_with_age/len(df_enriched)*100):.2f}%")
print(f"✓ Contacts without age data: {len(df_enriched) - total_with_age:,}")
print("=" * 80)

# Create filtered DataFrame with only contacts that have age data
age_contacts_df = contacts_with_age[contacts_with_age['has_any_age']].copy()

if not age_contacts_df.empty:
    print(f"\n📋 Sample of contacts with age data (first 20):")
    display_cols = ['id', 'email', 'firstName', 'lastName'] + age_columns
    display_cols = [c for c in display_cols if c in age_contacts_df.columns]
    display(age_contacts_df[display_cols].head(20))
    
    # Show age distribution if we can extract it
    print(f"\n📊 Age Data Analysis:")
    for col in age_columns:
        if col in age_contacts_df.columns:
            age_values = age_contacts_df[col].dropna()
            if not age_values.empty:
                print(f"\nAge values in '{col}':")
                print(age_values.value_counts().head(10))
    
    print(f"\n✓ Created 'age_contacts_df' with {len(age_contacts_df):,} contacts that have age data")
    print(f"✓ Created 'contacts_with_age' DataFrame with age flags")
else:
    print("\n⚠️  No contacts found with age data")
